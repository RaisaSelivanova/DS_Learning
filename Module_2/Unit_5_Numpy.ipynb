# %%
import numpy as np

# %%
a = np.int8(25)
print(a)
print(type(a))
# Out:
# 25
# <class 'numpy.int8'>

# %%
np.iinfo(np.int64)
# Out:
# iinfo(min=-9223372036854775808, max=9223372036854775807, dtype=int64)

# %%
b = np.uint8(124)
print(b)
# 124
print(type(b))
# <class 'numpy.uint8'>
np.iinfo(b)
# iinfo(min=0, max=255, dtype=uint8)
# Out:
# 124
# <class 'numpy.uint8'>
# iinfo(min=0, max=255, dtype=uint8)

# %%
b = np.int8(124)
print(b)
print(type(b))
np.iinfo(b)
# Out:
# 124
# <class 'numpy.int8'>
# iinfo(min=-128, max=127, dtype=int8)

# %%
a = np.uint8(-456)
print(a)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a = np.uint8(-456)
#       2 print(a)
#
# OverflowError: Python integer -456 out of bounds for uint8
