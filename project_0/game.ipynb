# %% [markdown]
# # Игра "Угадай число"

# %% [markdown]
# ## Угадываем рандомно

# %%
from game2 import score_game, random_predict
score_game(random_predict) #вызов функции
# Out:
# Количество попыток: 301
# Количество попыток: 35
# Ваш алгоритм угадывает число в среднем за: 101 попыток
# 101

# %%
n = 5
z = n
y = 4
